# %% [markdown]
# ## Lab 02 - Pandas and Data Visualization
# This notebook will introduce you to the basics of Pandas and Data Visualization. You will learn how to load data into a Pandas DataFrame, how to perform basic data analysis, and how to visualize data. The first part of this notebook will be an interactive tutorial, and the second part will be practice exercises for you to do! **Note that the practice problems will be checked when submitted!**

# %% [markdown]
# #### Pandas
# Pandas is a popular open-source Python library that provides data structures and data analysis tools for working with structured data. Pandas is a versatile library that simplifies data manipulation, analysis, and exploration in Python. Some of its uses:
# * Tabular Data Handling
# * Data Cleaning and Transformation
# * Data Exploration
# * Data Import/Export
# * Data Visualization
#
# #### Matplotlib
# Matplotlib is a widely used for creating static, animated, and interactive visualizations. Whether you are conducting data analysis, scientific research, or data communication, Matplotlib helps you present your findings effectively and intuitively.

# %% [markdown]
# ### Pre-requisites

# %%
# In case you don't have pandas, uncomment
# the following lines and run the cell

# %pip install pandas

# %% [markdown]
# ### Overview
# In this notebook, you will be learning how to use the Pandas library by working with the `cookies.csv` file.
#
# #### `cookies.csv` file :
#
# The `cookies.csv` file contains information about cookies that were made in Rico's Bisquito's factory.
#
# The columns are the following:
#
# `cookie`: the name of a cookie
# `ingredients`: a list of the cookie's ingredients
# `calories`: the number of calories the created cookie has
# `radius`: the radius of the created cookie, in cm
# `cost_to_make`: the cost it took to make the created cookie, in dollars

# %% [markdown]
# ### Reading the CSV file
#
# First, we need to import the Pandas library. We will be using the `pd` alias for the Pandas library.

# %%
#TODO: import pandas and matplotlib in this cell
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# We will now look at the `cookies.csv` file. We will use the `pd.read_csv()` function to read in the CSV file. We will store the data in a variable called `cookies`.

# %%
#TODO: read the cookies.csv file into a pandas dataframe
cookies = pd.read_csv("cookies.csv")
data = cookies

# %% [markdown]
# #### Dataframe
# Dataframes are a data structure that Pandas uses to store data. Dataframes are similar to tables in a database. Dataframes have rows and columns. Each row represents a single data point, and each column represents a feature of the data point.

# %% [markdown]
# We will then make sure we imported the data correctly by printing out the first 10 rows of the data, using the `head()` function.

# %%
#TODO: print the head of the dataframe
cookies.head(10)
# Out:
#             cookie                                        ingredients  \
# 0     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 1  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 2         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 3  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 4  bad berry bunny           ["flour","blueberries","sugar","butter"]
# 5     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 6      minty miami          ["flour","mint extract","sugar","butter"]
# 7        chocolate       ["flour","chocolate chips","sugar","butter"]
# 8     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 9      minty miami          ["flour","mint extract","sugar","butter"]
#
#    calories  radius  cost_to_make
# 0       170   3.102          0.67
# 1       198   3.780          1.07
# 2       224   4.069          1.04
# 3       198   3.780          1.07
# 4       191   4.148          1.39
# 5       162   3.241          1.15
# 6       204   3.964          0.84
# 7       243   3.684          1.17
# 8       178   3.989           NaN
# 9       184   3.743          0.74

# %% [markdown]
# ### Checking data types
# You can check the data types of each column using the `dtypes` attribute of the DataFrame.

# %%
#TODO: check the data types of the columns
for col in cookies:
    print("the data type of col \"" + col + "\" is", cookies[col].dtypes)
# Out:
# the data type of col "cookie" is object
# the data type of col "ingredients" is object
# the data type of col "calories" is int64
# the data type of col "radius" is float64
# the data type of col "cost_to_make" is float64

# %% [markdown]
# Now, lets use use `info()` function to get more information about the Dataframe

# %%
# TODO: use info() to get information about datatypes and null values
cookies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129 entries, 0 to 128
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cookie        129 non-null    object
#  1   ingredients   129 non-null    object
#  2   calories      129 non-null    int64
#  3   radius        129 non-null    float64
#  4   cost_to_make  114 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 5.2+ KB

# %% [markdown]
# ### Cleaning the data
# Now that we have the data, we need to clean it. For example, some `cost_to_make` fields of some created cookies are missing. To resolve this, we can do many things: we can replace the missing data with the mean of the column, or we can get rid of the row entirely if the `cost_to_make` field is not set.

# %%
#TODO: clean the dataframe and 
# print the head again to make sure 
# the changes took effect
cost_mean = cookies["cost_to_make"].mean()
cookies["cost_to_make"] = cookies["cost_to_make"].fillna(cost_mean)
cookies.head(10)
# Out:
#             cookie                                        ingredients  \
# 0     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 1  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 2         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 3  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 4  bad berry bunny           ["flour","blueberries","sugar","butter"]
# 5     orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 6      minty miami          ["flour","mint extract","sugar","butter"]
# 7        chocolate       ["flour","chocolate chips","sugar","butter"]
# 8     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 9      minty miami          ["flour","mint extract","sugar","butter"]
#
#    calories  radius  cost_to_make
# 0       170   3.102      0.670000
# 1       198   3.780      1.070000
# 2       224   4.069      1.040000
# 3       198   3.780      1.070000
# 4       191   4.148      1.390000
# 5       162   3.241      1.150000
# 6       204   3.964      0.840000
# 7       243   3.684      1.170000
# 8       178   3.989      1.176579
# 9       184   3.743      0.740000

# %% [markdown]
# To also make sure we removed null values, we can check the number of null values in each column using the `isnull()` function.

# %%
#TODO: use the isnull method to make sure your data is clean
cookies.isnull()
# Out:
#      cookie  ingredients  calories  radius  cost_to_make
# 0     False        False     False   False         False
# 1     False        False     False   False         False
# 2     False        False     False   False         False
# 3     False        False     False   False         False
# 4     False        False     False   False         False
# ..      ...          ...       ...     ...           ...
# 124   False        False     False   False         False
# 125   False        False     False   False         False
# 126   False        False     False   False         False
# 127   False        False     False   False         False
# 128   False        False     False   False         False
#
# [129 rows x 5 columns]

# %% [markdown]
# Next, lets check for duplicate rows using the `duplicated()` function. Then, remove those rows using `drop_duplicates()` function.

# %%
# TODO: check for duplicate rows
# then delete those rows form df
cookies.duplicated()
cookies = cookies.drop_duplicates()
cookies
# Out:
#               cookie                                        ingredients  \
# 0       laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 1    red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 2           nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 4    bad berry bunny           ["flour","blueberries","sugar","butter"]
# 5       orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# ..               ...                                                ...
# 121        chocolate       ["flour","chocolate chips","sugar","butter"]
# 122     laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 125         nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 126  red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 127  bad berry bunny           ["flour","blueberries","sugar","butter"]
#
#      calories  radius  cost_to_make
# 0         170   3.102          0.67
# 1         198   3.780          1.07
# 2         224   4.069          1.04
# 4         191   4.148          1.39
# 5         162   3.241          1.15
# ..        ...     ...           ...
# 121       227   4.085          1.42
# 122       170   3.916          2.00
# 125       211   3.915          1.61
# 126       197   3.906          1.33
# 127       199   4.281          1.36
#
# [118 rows x 5 columns]

# %% [markdown]
# ### Parsing the data
# Now that we have the data, we could parse it to get the information we want. For example, we can check what types of cookies were made by using the `unique()` function on the `cookie` column.

# %%
#TODO: see what cookies are in the dataset
unique = cookies["cookie"].unique()
print(unique)
# Out:
# ['laddoo lemon' 'red velvet rauw' 'nevadito' 'bad berry bunny'
#  'orange ozuna' 'minty miami' 'chocolate']

# %% [markdown]
# We can also check the number of cookies made by using the `value_counts()` function on the `cookie` column.

# %%
#TODO: use value_counts() to see how many 
# cookies of each type there are
cookies["cookie"].value_counts()
# Out:
# red velvet rauw    18
# laddoo lemon       17
# nevadito           17
# bad berry bunny    17
# orange ozuna       17
# minty miami        17
# chocolate          15
# Name: cookie, dtype: int64

# %% [markdown]
# Or maybe we don't like how long the names of the cookies are, so we can shorten them by using the `replace()` function on the `cookie` column.
#
# For example, let's try changing `"bad berry bunny"` to `"bbb"`.

# %%
#TODO: change bad berry bunny data elements to "bbb"
cookies["cookie"] = cookies["cookie"].replace("bad berry bunny", "bbb")
cookies.head(10)
# Out:
# /var/folders/6s/s07zzd5s4jd122qz1g8n80n40000gn/T/ipykernel_78573/1163280877.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cookies["cookie"] = cookies["cookie"].replace("bad berry bunny", "bbb")
#              cookie                                        ingredients  \
# 0      laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 1   red velvet rauw  ["flour","cocoa powder","butter","red food col...
# 2          nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 4               bbb           ["flour","blueberries","sugar","butter"]
# 5      orange ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 6       minty miami          ["flour","mint extract","sugar","butter"]
# 7         chocolate       ["flour","chocolate chips","sugar","butter"]
# 8      laddoo lemon             ["flour","lemon juice","sugar","ghee"]
# 9       minty miami          ["flour","mint extract","sugar","butter"]
# 10         nevadito  ["flour","chocolate chips","milk","vanilla ext...
#
#     calories  radius  cost_to_make
# 0        170   3.102      0.670000
# 1        198   3.780      1.070000
# 2        224   4.069      1.040000
# 4        191   4.148      1.390000
# 5        162   3.241      1.150000
# 6        204   3.964      0.840000
# 7        243   3.684      1.170000
# 8        178   3.989      1.176579
# 9        184   3.743      0.740000
# 10       216   3.848      1.280000

# %% [markdown]
# We may even like the original names better, but we may want to get rid of the spaces. For example, we can change `"orange ozuna"` to `"orange_ozuna"`. Here, we will use the `str.replace()` function.

# %%
#TODO: adjust orange ozuna as described
cookies["cookie"] = cookies["cookie"].str.replace(" ", "_")
cookies.head(10)
# Out:
# /var/folders/6s/s07zzd5s4jd122qz1g8n80n40000gn/T/ipykernel_78573/1643994985.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cookies["cookie"] = cookies["cookie"].str.replace(" ", "_")
#              cookie                                        ingredients  \
# 0      laddoo_lemon             ["flour","lemon juice","sugar","ghee"]
# 1   red_velvet_rauw  ["flour","cocoa powder","butter","red food col...
# 2          nevadito  ["flour","chocolate chips","milk","vanilla ext...
# 4               bbb           ["flour","blueberries","sugar","butter"]
# 5      orange_ozuna   ["flour","orange juice","sugar","vegetable oil"]
# 6       minty_miami          ["flour","mint extract","sugar","butter"]
# 7         chocolate       ["flour","chocolate chips","sugar","butter"]
# 8      laddoo_lemon             ["flour","lemon juice","sugar","ghee"]
# 9       minty_miami          ["flour","mint extract","sugar","butter"]
# 10         nevadito  ["flour","chocolate chips","milk","vanilla ext...
#
#     calories  radius  cost_to_make
# 0        170   3.102      0.670000
# 1        198   3.780      1.070000
# 2        224   4.069      1.040000
# 4        191   4.148      1.390000
# 5        162   3.241      1.150000
# 6        204   3.964      0.840000
# 7        243   3.684      1.170000
# 8        178   3.989      1.176579
# 9        184   3.743      0.740000
# 10       216   3.848      1.280000

# %% [markdown]
# We may even just want to keep the first word of the cookie name. For example, we can change `"orange_ozuna"` to `"orange"`.

# %%
#TODO: adjust all cookies so only the first word
# is used as the cookie name
cookies["cookie"]= cookies["cookie"].str.split("_").str[0]
cookies.head(10)
# Out:
# /var/folders/6s/s07zzd5s4jd122qz1g8n80n40000gn/T/ipykernel_78573/3844234048.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cookies["cookie"]= cookies["cookie"].str.split("_").str[0]
#        cookie                                        ingredients  calories  \
# 0      laddoo             ["flour","lemon juice","sugar","ghee"]       170
# 1         red  ["flour","cocoa powder","butter","red food col...       198
# 2    nevadito  ["flour","chocolate chips","milk","vanilla ext...       224
# 4         bbb           ["flour","blueberries","sugar","butter"]       191
# 5      orange   ["flour","orange juice","sugar","vegetable oil"]       162
# 6       minty          ["flour","mint extract","sugar","butter"]       204
# 7   chocolate       ["flour","chocolate chips","sugar","butter"]       243
# 8      laddoo             ["flour","lemon juice","sugar","ghee"]       178
# 9       minty          ["flour","mint extract","sugar","butter"]       184
# 10   nevadito  ["flour","chocolate chips","milk","vanilla ext...       216
#
#     radius  cost_to_make
# 0    3.102      0.670000
# 1    3.780      1.070000
# 2    4.069      1.040000
# 4    4.148      1.390000
# 5    3.241      1.150000
# 6    3.964      0.840000
# 7    3.684      1.170000
# 8    3.989      1.176579
# 9    3.743      0.740000
# 10   3.848      1.280000

# %% [markdown]
# Another thing that may come to mind is that maybe getting flour could cost more money due to inflation, so we have to adjust our `cost_to_make` values. We can do this by using the `apply()` function on the `cost_to_make` column.

# %%
#Don't edit this method
def adjust_cost(cost):
    return cost + 0.5

#TODO: use apply() to adjust the cost_to_make column.
cookies["cost_to_make"] = cookies["cost_to_make"].apply(lambda x: adjust_cost(x))
cookies.head()
# Out:
# /var/folders/6s/s07zzd5s4jd122qz1g8n80n40000gn/T/ipykernel_78573/415881152.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cookies["cost_to_make"] = cookies["cost_to_make"].apply(lambda x: adjust_cost(x))
#      cookie                                        ingredients  calories  \
# 0    laddoo             ["flour","lemon juice","sugar","ghee"]       170
# 1       red  ["flour","cocoa powder","butter","red food col...       198
# 2  nevadito  ["flour","chocolate chips","milk","vanilla ext...       224
# 4       bbb           ["flour","blueberries","sugar","butter"]       191
# 5    orange   ["flour","orange juice","sugar","vegetable oil"]       162
#
#    radius  cost_to_make
# 0   3.102          1.17
# 1   3.780          1.57
# 2   4.069          1.54
# 4   4.148          1.89
# 5   3.241          1.65

# %% [markdown]
# And we can do a lot more things! We will see these concepts be used in the next homework assignment, along with a couple new ones to show you how powerful Pandas is.

# %% [markdown]
# ### More complicated operations: Grouping, Filtering, Aggregating

# %% [markdown]
# Before trying out these complicated operations, lets first sort the sort the df by the radius of the cookies using the `sort_values()` function.

# %%
# TODO: sort the df using sort_values(by='Column', ascending=False)
sort_cookies = cookies.sort_values(by = "radius", ascending = False)
sort_cookies.head(10)
# Out:
#         cookie                                        ingredients  calories  \
# 110        red  ["flour","cocoa powder","butter","red food col...       198
# 30         red  ["flour","cocoa powder","butter","red food col...       204
# 109   nevadito  ["flour","chocolate chips","milk","vanilla ext...       211
# 60      orange   ["flour","orange juice","sugar","vegetable oil"]       186
# 49      laddoo             ["flour","lemon juice","sugar","ghee"]       195
# 101     laddoo             ["flour","lemon juice","sugar","ghee"]       178
# 97         red  ["flour","cocoa powder","butter","red food col...       191
# 87   chocolate       ["flour","chocolate chips","sugar","butter"]       199
# 80   chocolate       ["flour","chocolate chips","sugar","butter"]       197
# 72         red  ["flour","cocoa powder","butter","red food col...       196
#
#      radius  cost_to_make
# 110   4.930      1.550000
# 30    4.667      1.900000
# 109   4.619      1.676579
# 60    4.573      1.560000
# 49    4.562      1.120000
# 101   4.519      1.910000
# 97    4.475      1.740000
# 87    4.474      1.640000
# 80    4.461      2.170000
# 72    4.425      1.370000

# %% [markdown]
# We may also want to group data by certain attributes. This can be done by using `groupby()`. This method takes in a column name, and groups the data by the values in that column. For example, we can group the data by the `cookie` column.

# %%
#TODO: group by cookie type
grouped_by_cookie = cookies.groupby('cookie')

# %% [markdown]
# We can also group by multiple columns. For example, we can group the data by the `cookie` and `ingredients` columns.

# %%
#TODO: group by cookie type and ingredients
grouped_by_cookie_ingred = cookies.groupby(['cookie', 'ingredients'])

# %% [markdown]
# We may also want to filter the data. For example, we can filter the data to only show the cookies that have a radius greater than 4.3 cm. We can do this by indexing the DataFrame with a boolean expression.

# %%
#TODO: filter using the boolean expression
filter_cookies = cookies[cookies["radius"] > 4.3]
filter_cookies.head(10)
# Out:
#        cookie                                        ingredients  calories  \
# 29   nevadito  ["flour","chocolate chips","milk","vanilla ext...       219
# 30        red  ["flour","cocoa powder","butter","red food col...       204
# 47      minty          ["flour","mint extract","sugar","butter"]       174
# 49     laddoo             ["flour","lemon juice","sugar","ghee"]       195
# 60     orange   ["flour","orange juice","sugar","vegetable oil"]       186
# 62  chocolate       ["flour","chocolate chips","sugar","butter"]       206
# 72        red  ["flour","cocoa powder","butter","red food col...       196
# 76        red  ["flour","cocoa powder","butter","red food col...       206
# 80  chocolate       ["flour","chocolate chips","sugar","butter"]       197
# 87  chocolate       ["flour","chocolate chips","sugar","butter"]       199
#
#     radius  cost_to_make
# 29   4.346          1.68
# 30   4.667          1.90
# 47   4.388          1.14
# 49   4.562          1.12
# 60   4.573          1.56
# 62   4.328          1.84
# 72   4.425          1.37
# 76   4.319          1.74
# 80   4.461          2.17
# 87   4.474          1.64

# %% [markdown]
# We may even want to use `groupby()` and filter idea together! For example, we can filter the data to only show the cookies that have a radius greater than 4.3 cm, and group the data by the `cookie` column.

# %%
#TODO: filter the data using the boolean expression
# then group by cookie column
filter_groupby_cookie = filter_cookies.groupby('cookie')
filter_groupby_cookie.head(10)
# Out:
#         cookie                                        ingredients  calories  \
# 29    nevadito  ["flour","chocolate chips","milk","vanilla ext...       219
# 30         red  ["flour","cocoa powder","butter","red food col...       204
# 47       minty          ["flour","mint extract","sugar","butter"]       174
# 49      laddoo             ["flour","lemon juice","sugar","ghee"]       195
# 60      orange   ["flour","orange juice","sugar","vegetable oil"]       186
# 62   chocolate       ["flour","chocolate chips","sugar","butter"]       206
# 72         red  ["flour","cocoa powder","butter","red food col...       196
# 76         red  ["flour","cocoa powder","butter","red food col...       206
# 80   chocolate       ["flour","chocolate chips","sugar","butter"]       197
# 87   chocolate       ["flour","chocolate chips","sugar","butter"]       199
# 88      laddoo             ["flour","lemon juice","sugar","ghee"]       167
# 97         red  ["flour","cocoa powder","butter","red food col...       191
# 100      minty          ["flour","mint extract","sugar","butter"]       185
# 101     laddoo             ["flour","lemon juice","sugar","ghee"]       178
# 109   nevadito  ["flour","chocolate chips","milk","vanilla ext...       211
# 110        red  ["flour","cocoa powder","butter","red food col...       198
#
#      radius  cost_to_make
# 29    4.346      1.680000
# 30    4.667      1.900000
# 47    4.388      1.140000
# 49    4.562      1.120000
# 60    4.573      1.560000
# 62    4.328      1.840000
# 72    4.425      1.370000
# 76    4.319      1.740000
# 80    4.461      2.170000
# 87    4.474      1.640000
# 88    4.401      1.740000
# 97    4.475      1.740000
# 100   4.307      1.676579
# 101   4.519      1.910000
# 109   4.619      1.676579
# 110   4.930      1.550000

# %% [markdown]
# We may also want to aggregate the data. For example, we can aggregate the data by looking at the ratio of calories to radius. We can do this by using indexing and the `apply()` function.

# %%
#TODO: add a column to the dataframe that is the
# calories per radius
cookies['cal_radius_ratio'] = cookies.apply(lambda row: row['calories'] / row['radius'], axis = 1)
cookies.head()
# Out:
# /var/folders/6s/s07zzd5s4jd122qz1g8n80n40000gn/T/ipykernel_78573/1025557256.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cookies['cal_radius_ratio'] = cookies.apply(lambda row: row['calories'] / row['radius'], axis = 1)
#      cookie                                        ingredients  calories  \
# 0    laddoo             ["flour","lemon juice","sugar","ghee"]       170
# 1       red  ["flour","cocoa powder","butter","red food col...       198
# 2  nevadito  ["flour","chocolate chips","milk","vanilla ext...       224
# 4       bbb           ["flour","blueberries","sugar","butter"]       191
# 5    orange   ["flour","orange juice","sugar","vegetable oil"]       162
#
#    radius  cost_to_make  cal_radius_ratio
# 0   3.102          1.17         54.803353
# 1   3.780          1.57         52.380952
# 2   4.069          1.54         55.050381
# 4   4.148          1.89         46.046287
# 5   3.241          1.65         49.984573

# %% [markdown]
# Or we can just get rid of this column if we find it useless. We can do this by using the `drop()` function or indexing.

# %%
#TODO: drop the created column
cookies = cookies.drop(columns = ['cal_radius_ratio'])
cookies.head()
# Out:
#      cookie                                        ingredients  calories  \
# 0    laddoo             ["flour","lemon juice","sugar","ghee"]       170
# 1       red  ["flour","cocoa powder","butter","red food col...       198
# 2  nevadito  ["flour","chocolate chips","milk","vanilla ext...       224
# 4       bbb           ["flour","blueberries","sugar","butter"]       191
# 5    orange   ["flour","orange juice","sugar","vegetable oil"]       162
#
#    radius  cost_to_make
# 0   3.102          1.17
# 1   3.780          1.57
# 2   4.069          1.54
# 4   4.148          1.89
# 5   3.241          1.65

# %% [markdown]
# ### Visualizing the data

# %% [markdown]
# We can also visualize the data. For example, we can visualize the data by plotting the radius of the cookies against the cost to make the cookies. We can do this by using the `plot()` function.

# %%
#TODO: plot the radius (x) versus cost to make (y)
cookies.plot('radius', "cost_to_make", kind='scatter')
plt.show()

# %% [markdown]
# We may even want to get more specific and visualize the shape of a distribution of the `laddoo lemon`'s radius by making a boxplot. We can also do this by using the `plot()` function.

# %%
#TODO: add the described boxplot
# remember that you changed the name from laddoo lemon to laddoo
laddoo_cookies = cookies[cookies['cookie'] == 'laddoo']['radius']
laddoo_cookies.plot(kind='box', title='Boxplot of Laddoo Radius')
plt.show()

# %% [markdown]
# Alternatively, we can create a histogram to visualize the distribution of the `laddoo lemon`'s radius. We can also do this by using the `plot()` function.

# %%
#TODO: add the described histogram
plt.figure(figsize=(10,6))
laddoo_cookies.plot(kind='hist', title="Histogram of Laddoo Radius")
plt.show()

# %% [markdown]
# Things can get more complicated too. Maybe we want to analyze the behaviors of `bad berry bunny` and `laddoo lemon`'s radius using a boxplot. But this time, let's try it using the alternative `boxplot()` function. For practice, try doing it with `plot()` too!

# %%
#TODO: analyze the two cookie's radius in a boxplot
selected_cookies = cookies[cookies['cookie'].isin(['bbb', 'laddoo'])]
plt.figure(figsize=(10,6))
selected_cookies.boxplot(column='radius', by='cookie')
plt.title('Boxplot of Radius by Cookie Type')
plt.suptitle('') 
plt.show()

# %% [markdown]
# ### Practice Problems
# Now that you have learned some of Pandas' capabilities, let's try some practice problems! **This is the part that will be checked when you submit it!**

# %% [markdown]
# #### Problem 1
# How many cookies were made? (Hint: use the `shape` attribute)

# %%
#Add your code here
cookies.shape[0]
# Out:
# 118

# %% [markdown]
# #### Problem 2
# Add a column to the DataFrame that has the value `True` if the cookie has a radius greater than 4 cm, and `False` otherwise. (Hint: use the `apply()` function)

# %%
#Add your code here
cookies['radius_gt_4'] = cookies['radius'].apply(lambda x: x > 4)

# %%
cookies
# Out:
#         cookie                                        ingredients  calories  \
# 0       laddoo             ["flour","lemon juice","sugar","ghee"]       170
# 1          red  ["flour","cocoa powder","butter","red food col...       198
# 2     nevadito  ["flour","chocolate chips","milk","vanilla ext...       224
# 4          bbb           ["flour","blueberries","sugar","butter"]       191
# 5       orange   ["flour","orange juice","sugar","vegetable oil"]       162
# ..         ...                                                ...       ...
# 121  chocolate       ["flour","chocolate chips","sugar","butter"]       227
# 122     laddoo             ["flour","lemon juice","sugar","ghee"]       170
# 125   nevadito  ["flour","chocolate chips","milk","vanilla ext...       211
# 126        red  ["flour","cocoa powder","butter","red food col...       197
# 127        bbb           ["flour","blueberries","sugar","butter"]       199
#
#      radius  cost_to_make  radius_gt_4
# 0     3.102          1.17        False
# 1     3.780          1.57        False
# 2     4.069          1.54         True
# 4     4.148          1.89         True
# 5     3.241          1.65        False
# ..      ...           ...          ...
# 121   4.085          1.92         True
# 122   3.916          2.50        False
# 125   3.915          2.11        False
# 126   3.906          1.83        False
# 127   4.281          1.86         True
#
# [118 rows x 6 columns]

# %% [markdown]
# #### Problem 3
#
# Group the data by the `cookie` column, and find the average radius of each cookie. (Hint: use the `groupby()` and `transform()` function). Add this column to the DataFrame.

# %%
#Add your code here
cookies['avg_radius_by_cookie'] = cookies.groupby('cookie')['radius'].transform('mean')

# %% [markdown]
# #### Problem 4
# Create a new DataFrame that only contains the cookies that have the ingredient `"chocolate chips"`. (Hint: use the `str.contains()` function)

# %%
#Add your code here
chocolate_chips = cookies[cookies['ingredients'].str.contains('chocolate chips')]
chocolate_chips
# Out:
#         cookie                                        ingredients  calories  \
# 2     nevadito  ["flour","chocolate chips","milk","vanilla ext...       224
# 7    chocolate       ["flour","chocolate chips","sugar","butter"]       243
# 10    nevadito  ["flour","chocolate chips","milk","vanilla ext...       216
# 17   chocolate       ["flour","chocolate chips","sugar","butter"]       209
# 19    nevadito  ["flour","chocolate chips","milk","vanilla ext...       236
# 25   chocolate       ["flour","chocolate chips","sugar","butter"]       205
# 29    nevadito  ["flour","chocolate chips","milk","vanilla ext...       219
# 34   chocolate       ["flour","chocolate chips","sugar","butter"]       205
# 36    nevadito  ["flour","chocolate chips","milk","vanilla ext...       211
# 41   chocolate       ["flour","chocolate chips","sugar","butter"]       206
# 43    nevadito  ["flour","chocolate chips","milk","vanilla ext...       205
# 48   chocolate       ["flour","chocolate chips","sugar","butter"]       240
# 50    nevadito  ["flour","chocolate chips","milk","vanilla ext...       220
# 55   chocolate       ["flour","chocolate chips","sugar","butter"]       229
# 57    nevadito  ["flour","chocolate chips","milk","vanilla ext...       208
# 62   chocolate       ["flour","chocolate chips","sugar","butter"]       206
# 64    nevadito  ["flour","chocolate chips","milk","vanilla ext...       211
# 69   chocolate       ["flour","chocolate chips","sugar","butter"]       216
# 71    nevadito  ["flour","chocolate chips","milk","vanilla ext...       214
# 80   chocolate       ["flour","chocolate chips","sugar","butter"]       197
# 82    nevadito  ["flour","chocolate chips","milk","vanilla ext...       253
# 87   chocolate       ["flour","chocolate chips","sugar","butter"]       199
# 89    nevadito  ["flour","chocolate chips","milk","vanilla ext...       249
# 94   chocolate       ["flour","chocolate chips","sugar","butter"]       243
# 96    nevadito  ["flour","chocolate chips","milk","vanilla ext...       230
# 102   nevadito  ["flour","chocolate chips","milk","vanilla ext...       229
# 107  chocolate       ["flour","chocolate chips","sugar","butter"]       222
# 109   nevadito  ["flour","chocolate chips","milk","vanilla ext...       211
# 114  chocolate       ["flour","chocolate chips","sugar","butter"]       226
# 116   nevadito  ["flour","chocolate chips","milk","vanilla ext...       216
# 121  chocolate       ["flour","chocolate chips","sugar","butter"]       227
# 125   nevadito  ["flour","chocolate chips","milk","vanilla ext...       211
#
#      radius  cost_to_make  radius_gt_4  avg_radius_by_cookie
# 2     4.069      1.540000         True              4.013588
# 7     3.684      1.670000        False              3.983667
# 10    3.848      1.780000        False              4.013588
# 17    3.182      2.030000        False              3.983667
# 19    4.043      1.790000         True              4.013588
# 25    3.383      1.676579        False              3.983667
# 29    4.346      1.680000         True              4.013588
# 34    3.937      1.676579        False              3.983667
# 36    4.152      2.220000         True              4.013588
# 41    3.681      1.676579        False              3.983667
# 43    3.776      1.460000        False              4.013588
# 48    4.212      1.470000         True              3.983667
# 50    3.855      2.710000        False              4.013588
# 55    4.217      1.690000         True              3.983667
# 57    3.583      1.920000        False              4.013588
# 62    4.328      1.840000         True              3.983667
# 64    4.205      1.690000         True              4.013588
# 69    3.824      1.650000        False              3.983667
# 71    4.141      1.870000         True              4.013588
# 80    4.461      2.170000         True              3.983667
# 82    4.043      1.620000         True              4.013588
# 87    4.474      1.640000         True              3.983667
# 89    3.819      1.630000        False              4.013588
# 94    4.207      1.640000         True              3.983667
# 96    3.788      1.660000        False              4.013588
# 102   3.802      2.290000        False              4.013588
# 107   4.186      1.360000         True              3.983667
# 109   4.619      1.676579         True              4.013588
# 114   3.894      1.450000        False              3.983667
# 116   4.227      1.676579         True              4.013588
# 121   4.085      1.920000         True              3.983667
# 125   3.915      2.110000        False              4.013588

# %% [markdown]
# #### Problem 5
#
# Create a boxplot of `cost_to_make` for all cookies except `chocolate` using the `boxplot()` function.

# %%
#Add your code here
non_chocolate_cookies = cookies[~cookies['ingredients'].str.contains("chocolate", case=False, na=False)]
non_chocolate_cookies.boxplot(column='cost_to_make')
plt.title('Boxplot of cost_to_make excluding chocolate')
plt.show()

# %% [markdown]
# #### Problem 6
#
# Create a histogram of the `bad berry bunny`'s calories using the `plot()` function.

# %%
#Add your code here
plt.figure(figsize=(10,6))
bbb_cookies = cookies[cookies['cookie'] == 'bbb']['radius']
bbb_cookies.plot(kind='hist', title="Histogram of bbb Radius")
plt.show()

# %% [markdown]
# #### Problem 7
#
# Calculate the average calories per cookie type and display the result in a bar chart.

# %%
#Add your code here
avg_cal_cookies = cookies.groupby('cookie')['calories'].mean()
avg_cal_cookies.plot(kind = 'bar')
plt.title('Average Calories per Cookie Type')
plt.ylabel('Calories')
plt.show()

# %% [markdown]
# #### Problem 8
#
# Find the top 3 most expensive cookies in terms of cost_to_make

# %%
#Add your code here
top_3_exp_cookies = cookies.nlargest(3, 'cost_to_make')
print(top_3_exp_cookies[['cookie', 'cost_to_make']])
# Out:
#       cookie  cost_to_make
# 42    laddoo          2.77
# 50  nevadito          2.71
# 13    orange          2.59
